# %%
import pandas as pd
import geopandas as gpd

# %%
data = pd.read_csv("Data/chipotle_stores.csv")
data.head(10)
# Out:
#      state    location                                            address  \
# 0  Alabama      Auburn             346 W Magnolia Ave Auburn, AL 36832 US
# 1  Alabama  Birmingham              300 20th St S Birmingham, AL 35233 US
# 2  Alabama  Birmingham             3220 Morrow Rd Birmingham, AL 35235 US
# 3  Alabama  Birmingham           4719 Highway 280 Birmingham, AL 35242 US
# 4  Alabama     Cullman          1821 Cherokee Ave SW Cullman, AL 35055 US
# 5  Alabama      Hoover            1759 Montgomery Hwy Hoover, AL 35244 US
# 6  Alabama  Huntsville  5900 University Dr NW Ste D2 Huntsville, AL 35...
# 7  Alabama      Mobile              3871 Airport Blvd Mobile, AL 36608 US
# 8  Alabama      Mobile         7765 Airport Blvd D100 Mobile, AL 36608 US
# 9  Alabama  Montgomery    2560 Berryhill Rd Ste C Montgomery, AL 36117 US
#
#     latitude  longitude
# 0  32.606813 -85.487328
# 1  33.509721 -86.802756
# 2  33.595581 -86.647437
# 3  33.422582 -86.698279
# 4  34.154134 -86.841220
# 5  33.378958 -86.803802
# 6  34.742319 -86.665720
# 7  30.675338 -88.143754
# 8  30.682731 -88.224998
# 9  32.359177 -86.162253

# %%
contiguous_usa = gpd.read_file("cb_2018_us_state_20m.shp")
contiguous_usa.head()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona\_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona\_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: cb_2018_us_state_20m.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-12-d38dc8bd631a> in <module>
# ----> 1 contiguous_usa = gpd.read_file("cb_2018_us_state_20m.shp")
#       2 contiguous_usa.head()
#
# ~\anaconda3\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#      94
#      95     with fiona_env():
# ---> 96         with reader(path_or_bytes, **kwargs) as features:
#      97
#      98             # In a future Fiona release the crs attribute of features will
#
# ~\anaconda3\lib\site-packages\fiona\env.py in wrapper(*args, **kwargs)
#     398     def wrapper(*args, **kwargs):
#     399         if local._env:
# --> 400             return f(*args, **kwargs)
#     401         else:
#     402             if isinstance(args[0], str):
#
# ~\anaconda3\lib\site-packages\fiona\__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     257
#     258         if mode in ('a', 'r'):
# --> 259             c = Collection(path, mode, driver=driver, encoding=encoding,
#     260                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     261         elif mode == 'w':
#
# ~\anaconda3\lib\site-packages\fiona\collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160             if self.mode == 'r':
#     161                 self.session = Session()
# --> 162                 self.session.start(self, **kwargs)
#     163             elif self.mode in ('a', 'w'):
#     164                 self.session = WritingSession()
#
# fiona\ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona\_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: cb_2018_us_state_20m.shp: No such file or directory
